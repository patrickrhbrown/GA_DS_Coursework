# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pwd
# Out:
# /Users/patrickrhbrown/Documents/GitHub/General-Assembly-Data-Science-Coursework-2017/Final_Project

# %%
df = pd.read_csv('Data/London.csv')
df = df[1:]

# %%
df.head()
# Out:
#         Code   New code             Area name Inner/ Outer London  \
# 1  E09000001  E09000001        City of London        Inner London
# 2  E09000002  E09000002  Barking and Dagenham        Outer London
# 3  E09000003  E09000003                Barnet        Outer London
# 4  E09000004  E09000004                Bexley        Outer London
# 5  E09000005  E09000005                 Brent        Outer London
#
#   GLA Population Estimate 2016 GLA Household Estimate 2016  \
# 1                       8,548                       5,179
# 2                     205,773                      76,841
# 3                     385,108                     149,147
# 4                     243,303                      97,233
# 5                     328,568                     119,166
#
#   Inland Area (Hectares) Population density (per hectare) 2016  \
# 1                  290.4                                  28.9
# 2                3,610.8                                  57.3
# ...

# %%
g = sns.pairplot(df)
plt.show()

# %%
df.describe()
# Out:
#        Average Age, 2016  Proportion of population aged 0-15, 2016  \
# count          39.000000                                 39.000000
# mean           36.476923                                 19.648718
# std             2.483574                                  2.912755
# min            31.300000                                  8.800000
# 25%            34.900000                                 18.550000
# 50%            36.200000                                 20.400000
# 75%            38.400000                                 21.100000
# max            42.900000                                 27.200000
#
#        Proportion of population of working-age, 2016  \
# count                                      39.000000
# mean                                       83.930769
# std                                        15.421723
# min                                        32.200000
# 25%                                        85.450000
# ...

# %%
df.dtypes
# Out:
# Code                                                                                                 object
# New code                                                                                             object
# Area name                                                                                            object
# Inner/ Outer London                                                                                  object
# GLA Population Estimate 2016                                                                         object
# GLA Household Estimate 2016                                                                          object
# Inland Area (Hectares)                                                                               object
# Population density (per hectare) 2016                                                                object
# Average Age, 2016                                                                                   float64
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of          Code   New code               Area name Inner/ Outer London  \
# 1   E09000001  E09000001          City of London        Inner London
# 2   E09000002  E09000002    Barking and Dagenham        Outer London
# 3   E09000003  E09000003                  Barnet        Outer London
# 4   E09000004  E09000004                  Bexley        Outer London
# 5   E09000005  E09000005                   Brent        Outer London
# 6   E09000006  E09000006                 Bromley        Outer London
# 7   E09000007  E09000007                  Camden        Inner London
# 8   E09000008  E09000008                 Croydon        Outer London
# 9   E09000009  E09000009                  Ealing        Outer London
# 10  E09000010  E09000010                 Enfield        Outer London
# 11  E09000011  E09000011               Greenwich        Outer London
# 12  E09000012  E09000012                 Hackney        Inner London
# ...
